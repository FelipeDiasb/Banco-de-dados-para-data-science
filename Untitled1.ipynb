# %%
import pandas as pd

# %%
import os

# %%
print(os.listdir("C:/Users/02.felipe.barbosa/Desktop"))
# Out:
# ['AcruxMonitorPDV.url', 'BANCOS.rdp', 'Cipa-2024.rdp', 'Cofre_PMP.url', 'desktop.ini', 'FlowRack.csv', 'Fluig.url', 'GERAR OS.lnk', 'GerenciadordeAssinatura.rdp', 'Gerencia_Robos.rdp', 'Melhoria Continua Compartilha.url', 'Niduu.url', 'Qualiex.url', 'SGE.rdp', 'Sitef_Motor.url', 'SoftCom.lnk', 'SysAid.url', 'Teams.url', 'Webmail O365.url', 'Wiki.url', 'Winthor.lnk']

# %%
dados = pd.read_csv('C:/Users/02.felipe.barbosa/Desktop/FlowRack.csv', sep = ";")
dados.head(20)
# Out:
#           DATA       NUMOS  CODPROD TOTAL_VOLUMEM3  \
# 0   01/07/2025  78668605.0  54611.0     0,00091908
# 1   01/07/2025  78668605.0  73930.0        0,02112
# 2   01/07/2025  78668605.0  58315.0       0,018297
# 3   01/07/2025  78668606.0  33469.0     0,02058684
# 4   01/07/2025  78668606.0  77096.0     0,00229806
# 5   01/07/2025  78668606.0  32483.0      0,0017178
# 6   01/07/2025  78668606.0  56283.0     0,00555008
# 7   01/07/2025  78668606.0  54611.0     0,00398268
# 8   01/07/2025  78668606.0  76476.0       0,005889
# 9   01/07/2025  78668607.0   7380.0     0,00025906
# 10  01/07/2025  78668607.0  16495.0     0,00117216
# 11  01/07/2025  78668607.0  29688.0     0,03136441
# 12  01/07/2025  78668607.0  56620.0     0,00171432
# 13  01/07/2025  78668688.0  58315.0      0,0073188
# 14  01/07/2025  78668688.0  54024.0       0,005735
# 15  01/07/2025  78668688.0  56633.0      0,0191856
# 16  01/07/2025  78668688.0  38440.0     0,00308518
# ...

# %%
display(dados)
# Out:
#              DATA       NUMOS  CODPROD TOTAL_VOLUMEM3  \
# 0      01/07/2025  78668605.0  54611.0     0,00091908
# 1      01/07/2025  78668605.0  73930.0        0,02112
# 2      01/07/2025  78668605.0  58315.0       0,018297
# 3      01/07/2025  78668606.0  33469.0     0,02058684
# 4      01/07/2025  78668606.0  77096.0     0,00229806
# ...           ...         ...      ...            ...
# 88583         NaN         NaN      NaN            NaN
# 88584         NaN         NaN      NaN            NaN
# 88585         NaN         NaN      NaN            NaN
# 88586         NaN         NaN      NaN            NaN
# 88587         NaN         NaN      NaN            NaN
#
#                                       DESCRICAO QTEMCX
# 0              ATUM RALADO ROBINSON CRUSOE OLEO    0,1
# 1                CHICLE BUZZY TATTOO TRIBAL UVA    0,8
# 2                    FLOCAO DE MILHO DONA CLARA    0,7
# 3                         CHOC.NESTLE PRESTIGIO    0,5
# ...

# %%
display(dados.head(5))
# Out:
#          DATA       NUMOS  CODPROD TOTAL_VOLUMEM3  \
# 0  01/07/2025  78668605.0  54611.0     0,00091908
# 1  01/07/2025  78668605.0  73930.0        0,02112
# 2  01/07/2025  78668605.0  58315.0       0,018297
# 3  01/07/2025  78668606.0  33469.0     0,02058684
# 4  01/07/2025  78668606.0  77096.0     0,00229806
#
#                                   DESCRICAO QTEMCX
# 0          ATUM RALADO ROBINSON CRUSOE OLEO    0,1
# 1            CHICLE BUZZY TATTOO TRIBAL UVA    0,8
# 2                FLOCAO DE MILHO DONA CLARA    0,7
# 3                     CHOC.NESTLE PRESTIGIO    0,5
# 4  CHOC.HERSHEYS SPECIAL DARK 47%CARAM.SALG    0,3

# %%
print(dados.head(20))
# Out:
#           DATA       NUMOS  CODPROD TOTAL_VOLUMEM3  \
# 0   01/07/2025  78668605.0  54611.0     0,00091908
# 1   01/07/2025  78668605.0  73930.0        0,02112
# 2   01/07/2025  78668605.0  58315.0       0,018297
# 3   01/07/2025  78668606.0  33469.0     0,02058684
# 4   01/07/2025  78668606.0  77096.0     0,00229806
# 5   01/07/2025  78668606.0  32483.0      0,0017178
# 6   01/07/2025  78668606.0  56283.0     0,00555008
# 7   01/07/2025  78668606.0  54611.0     0,00398268
# 8   01/07/2025  78668606.0  76476.0       0,005889
# 9   01/07/2025  78668607.0   7380.0     0,00025906
# 10  01/07/2025  78668607.0  16495.0     0,00117216
# 11  01/07/2025  78668607.0  29688.0     0,03136441
# 12  01/07/2025  78668607.0  56620.0     0,00171432
# 13  01/07/2025  78668688.0  58315.0      0,0073188
# 14  01/07/2025  78668688.0  54024.0       0,005735
# 15  01/07/2025  78668688.0  56633.0      0,0191856
# 16  01/07/2025  78668688.0  38440.0     0,00308518
# ...
